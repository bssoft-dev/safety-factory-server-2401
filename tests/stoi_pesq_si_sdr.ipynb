# %%
from pystoi import stoi
from pesq import pesq
import numpy as np
import soundfile as sf
import os

# %%
def measure_audio_quality(clean_file, noisy_file, sample_rate=16000):
    """
    음성 파일의 STOI와 PESQ 품질을 측정하는 함수
    
    Parameters:
    - clean_file: 원본 깨끗한 음성 파일 경로
    - noisy_file: 노이즈가 추가된 음성 파일 경로
    - sample_rate: 오디오 샘플링 레이트 (기본값 16000 Hz)
    
    Returns:
    - Dictionary containing STOI and PESQ scores
    """
    # 오디오 파일 로드
    clean_data, _ = sf.read(clean_file)
    if len(clean_data.shape) > 1:
        clean_data = clean_data[:, 0]
    noisy_data, _ = sf.read(noisy_file)
    if len(noisy_data.shape) > 1:
        noisy_data = noisy_data[:, 0]
    
    # STOI 측정
    # STOI는 0-1 사이의 값, 1에 가까울수록 음성 명료도 높음
    stoi_score = stoi(clean_data, noisy_data, sample_rate)
    
    # PESQ 측정
    # PESQ는 -0.5에서 4.5 사이의 값, 4.5에 가까울수록 음성 품질 우수
    # 'wb' 모드는 광대역(wide-band) 음성에 적합
    pesq_score = pesq(sample_rate, clean_data, noisy_data, 'wb')
    
    return {
        'STOI': stoi_score,
        'PESQ': pesq_score
    }

# %%
from si_sdr import si_sdr

def measure_si_sdr(clean_file, noisy_file):
    # 오디오 파일 로드
    clean_data, _ = sf.read(clean_file)
    if len(clean_data.shape) > 1:
        clean_data = clean_data[:, 0]
    if clean_data.dtype == np.int16:
        clean_data = (clean_data / 32768.0).astype(np.float64)
    noisy_data, _ = sf.read(noisy_file)
    if len(noisy_data.shape) > 1:
        noisy_data = noisy_data[:, 0]
    if noisy_data.dtype == np.int16:
        noisy_data = (noisy_data / 32768.0).astype(np.float64)
    si_sdr_score = si_sdr(clean_data, noisy_data)
    return si_sdr_score

# %%
if __name__ == "__main__":
    SIG_DIR = "sounds/before_noise"
    NOISY_DIR = "sounds/after_noise"
    DENOISED_DIR = "sounds/after_noise_denoised"
    
    for file in os.listdir(NOISY_DIR):
        if not file.endswith(".wav"):
            continue
        clean_file = os.path.join(SIG_DIR, f'{file.split("_")[0]}.wav')
        noisy_file = os.path.join(NOISY_DIR, file)
        denoised_file = os.path.join(DENOISED_DIR, file)
        quality_scores = measure_audio_quality(clean_file, noisy_file)
        denoised_quality_scores = measure_audio_quality(clean_file, denoised_file)
        print(f"노이즈제거 전: {file}, STOI: {quality_scores['STOI']:.4f}, PESQ: {quality_scores['PESQ']:.4f}")
        print(f"노이즈제거 후: {file}, STOI: {denoised_quality_scores['STOI']:.4f}, PESQ: {denoised_quality_scores['PESQ']:.4f}")
# Out:
# 노이즈제거 전: speech4_단열폼 미장 소음.wav, STOI: 0.6045, PESQ: 1.0917
# 노이즈제거 후: speech4_단열폼 미장 소음.wav, STOI: 0.5415, PESQ: 1.1236
# 노이즈제거 전: speech4_대형 환기팬 및 설비 소음.wav, STOI: 0.7086, PESQ: 1.1352
# 노이즈제거 후: speech4_대형 환기팬 및 설비 소음.wav, STOI: 0.6922, PESQ: 1.2234
# 노이즈제거 전: speech3_보온 작업 근접 소음 및 선박 망치질.wav, STOI: 0.6944, PESQ: 1.0778
# 노이즈제거 후: speech3_보온 작업 근접 소음 및 선박 망치질.wav, STOI: 0.7767, PESQ: 1.5971
# 노이즈제거 전: speech5_보온 작업 근접 소음 및 선박 망치질.wav, STOI: 0.6339, PESQ: 1.0720
# 노이즈제거 후: speech5_보온 작업 근접 소음 및 선박 망치질.wav, STOI: 0.7554, PESQ: 1.3734
# 노이즈제거 전: speech3_대형 환기팬 및 설비 소음.wav, STOI: 0.7680, PESQ: 1.1921
# 노이즈제거 후: speech3_대형 환기팬 및 설비 소음.wav, STOI: 0.8386, PESQ: 1.6425
# 노이즈제거 전: speech4_스프레이 작업 소음 (고음).wav, STOI: 0.5899, PESQ: 1.0699
# 노이즈제거 후: speech4_스프레이 작업 소음 (고음).wav, STOI: 0.6671, PESQ: 1.2349
# 노이즈제거 전: speech5_대형 환기팬 및 설비 소음.wav, STOI: 0.7152, PESQ: 1.1098
# 노이즈제거 후: speech5_대형 환기팬 및 설비 소음.wav, STOI: 0.8031, PESQ: 1.5098
# 노이즈제거 전: speech2_초고속 모터 작업 소음.wav, STOI: 0.7756, PESQ: 1.2344
# 노이즈제거 후: speech2_초고속 모터 작업 소음.wav, STOI: 0.8700, PESQ: 1.6441
# 노이즈제거 전: speech3_저속 스프레이 작업 소음 (직접).wav, STOI: 0.6781, PESQ: 1.0796
# 노이즈제거 후: speech3_저속 스프레이 작업 소음 (직접).wav, STOI: 0.7804, PESQ: 1.5967
# 노이즈제거 전: speech3_스프레이 작업 소음 (저음).wav, STOI: 0.6834, PESQ: 1.0504
# 노이즈제거 후: speech3_스프레이 작업 소음 (저음).wav, STOI: 0.7895, PESQ: 1.4664
# 노이즈제거 전: speech2_스프레이 마감작업 소음.wav, STOI: 0.7476, PESQ: 1.0665
# 노이즈제거 후: speech2_스프레이 마감작업 소음.wav, STOI: 0.9138, PESQ: 1.7131
# 노이즈제거 전: speech4_단열폼 분쇄기 소음.wav, STOI: 0.6756, PESQ: 1.1250
# 노이즈제거 후: speech4_단열폼 분쇄기 소음.wav, STOI: 0.7128, PESQ: 1.4116
# 노이즈제거 전: speech4_보온 작업 근접 소음 및 선박 망치질.wav, STOI: 0.6156, PESQ: 1.0894
# 노이즈제거 후: speech4_보온 작업 근접 소음 및 선박 망치질.wav, STOI: 0.6597, PESQ: 1.2206
# 노이즈제거 전: speech3_단열폼 분쇄기 소음.wav, STOI: 0.7413, PESQ: 1.3250
# 노이즈제거 후: speech3_단열폼 분쇄기 소음.wav, STOI: 0.8377, PESQ: 1.7142
# 노이즈제거 전: speech5_초고속 모터 작업 소음.wav, STOI: 0.6872, PESQ: 1.1965
# 노이즈제거 후: speech5_초고속 모터 작업 소음.wav, STOI: 0.7767, PESQ: 1.4525
# 노이즈제거 전: speech1_보온 작업 근접 소음 및 선박 망치질.wav, STOI: 0.6568, PESQ: 1.0897
# 노이즈제거 후: speech1_보온 작업 근접 소음 및 선박 망치질.wav, STOI: 0.8055, PESQ: 1.4734
# 노이즈제거 전: speech1_저속 스프레이 작업 소음 (장애물통과).wav, STOI: 0.6515, PESQ: 1.0809
# 노이즈제거 후: speech1_저속 스프레이 작업 소음 (장애물통과).wav, STOI: 0.7958, PESQ: 1.5307
# 노이즈제거 전: speech1_스프레이 작업 소음 (저음).wav, STOI: 0.6580, PESQ: 1.0545
# 노이즈제거 후: speech1_스프레이 작업 소음 (저음).wav, STOI: 0.7872, PESQ: 1.4027
# 노이즈제거 전: speech2_보온 작업 근접 소음 및 선박 망치질.wav, STOI: 0.7197, PESQ: 1.0558
# 노이즈제거 후: speech2_보온 작업 근접 소음 및 선박 망치질.wav, STOI: 0.8655, PESQ: 1.6210
# 노이즈제거 전: speech4_스프레이 작업 소음 (저음).wav, STOI: 0.6094, PESQ: 1.0718
# 노이즈제거 후: speech4_스프레이 작업 소음 (저음).wav, STOI: 0.6520, PESQ: 1.1456
# 노이즈제거 전: speech3_단열폼 미장 소음.wav, STOI: 0.6810, PESQ: 1.0929
# 노이즈제거 후: speech3_단열폼 미장 소음.wav, STOI: 0.8235, PESQ: 1.6757
# 노이즈제거 전: speech2_스프레이 작업 소음 (저음).wav, STOI: 0.7014, PESQ: 1.0373
# 노이즈제거 후: speech2_스프레이 작업 소음 (저음).wav, STOI: 0.8548, PESQ: 1.3827
# 노이즈제거 전: speech1_단열폼 미장 소음.wav, STOI: 0.6436, PESQ: 1.1209
# 노이즈제거 후: speech1_단열폼 미장 소음.wav, STOI: 0.8227, PESQ: 1.6440
# 노이즈제거 전: speech5_단열폼 분쇄기 소음.wav, STOI: 0.6943, PESQ: 1.2233
# 노이즈제거 후: speech5_단열폼 분쇄기 소음.wav, STOI: 0.7887, PESQ: 1.5414
# 노이즈제거 전: speech5_저속 스프레이 작업 소음 (직접).wav, STOI: 0.6177, PESQ: 1.0722
# 노이즈제거 후: speech5_저속 스프레이 작업 소음 (직접).wav, STOI: 0.7270, PESQ: 1.5052
# 노이즈제거 전: speech1_스프레이 작업 소음 (고음).wav, STOI: 0.6824, PESQ: 1.0565
# 노이즈제거 후: speech1_스프레이 작업 소음 (고음).wav, STOI: 0.8045, PESQ: 1.4064
# 노이즈제거 전: speech2_스프레이 작업 소음 (고음).wav, STOI: 0.7101, PESQ: 1.0367
# 노이즈제거 후: speech2_스프레이 작업 소음 (고음).wav, STOI: 0.8504, PESQ: 1.4146
# 노이즈제거 전: speech1_대형 환기팬 및 설비 소음.wav, STOI: 0.7622, PESQ: 1.1767
# 노이즈제거 후: speech1_대형 환기팬 및 설비 소음.wav, STOI: 0.8512, PESQ: 1.5980
# 노이즈제거 전: speech4_초고속 모터 작업 소음.wav, STOI: 0.6921, PESQ: 1.1335
# 노이즈제거 후: speech4_초고속 모터 작업 소음.wav, STOI: 0.7239, PESQ: 1.2615
# 노이즈제거 전: speech4_저속 스프레이 작업 소음 (장애물통과).wav, STOI: 0.6329, PESQ: 1.0907
# 노이즈제거 후: speech4_저속 스프레이 작업 소음 (장애물통과).wav, STOI: 0.6373, PESQ: 1.2063
# 노이즈제거 전: speech1_스프레이 마감작업 소음.wav, STOI: 0.7235, PESQ: 1.0646
# 노이즈제거 후: speech1_스프레이 마감작업 소음.wav, STOI: 0.8237, PESQ: 1.5484
# 노이즈제거 전: speech3_스프레이 마감작업 소음.wav, STOI: 0.6893, PESQ: 1.0969
# 노이즈제거 후: speech3_스프레이 마감작업 소음.wav, STOI: 0.8390, PESQ: 1.8480
# 노이즈제거 전: speech2_단열폼 분쇄기 소음.wav, STOI: 0.7749, PESQ: 1.2189
# 노이즈제거 후: speech2_단열폼 분쇄기 소음.wav, STOI: 0.8802, PESQ: 1.7391
# 노이즈제거 전: speech1_저속 스프레이 작업 소음 (직접).wav, STOI: 0.6327, PESQ: 1.0759
# 노이즈제거 후: speech1_저속 스프레이 작업 소음 (직접).wav, STOI: 0.7706, PESQ: 1.4694
# 노이즈제거 전: speech2_대형 환기팬 및 설비 소음.wav, STOI: 0.8054, PESQ: 1.2526
# 노이즈제거 후: speech2_대형 환기팬 및 설비 소음.wav, STOI: 0.8877, PESQ: 1.6111
# 노이즈제거 전: speech5_스프레이 마감작업 소음.wav, STOI: 0.6684, PESQ: 1.0780
# 노이즈제거 후: speech5_스프레이 마감작업 소음.wav, STOI: 0.7843, PESQ: 1.2050
# 노이즈제거 전: speech4_저속 스프레이 작업 소음 (직접).wav, STOI: 0.5940, PESQ: 1.0823
# 노이즈제거 후: speech4_저속 스프레이 작업 소음 (직접).wav, STOI: 0.5799, PESQ: 1.1685
# 노이즈제거 전: speech3_스프레이 작업 소음 (고음).wav, STOI: 0.6718, PESQ: 1.0555
# 노이즈제거 후: speech3_스프레이 작업 소음 (고음).wav, STOI: 0.7774, PESQ: 1.4837
# 노이즈제거 전: speech3_저속 스프레이 작업 소음 (장애물통과).wav, STOI: 0.6658, PESQ: 1.0688
# 노이즈제거 후: speech3_저속 스프레이 작업 소음 (장애물통과).wav, STOI: 0.8011, PESQ: 1.6068
# 노이즈제거 전: speech5_저속 스프레이 작업 소음 (장애물통과).wav, STOI: 0.6437, PESQ: 1.0706
# 노이즈제거 후: speech5_저속 스프레이 작업 소음 (장애물통과).wav, STOI: 0.7305, PESQ: 1.4293
# 노이즈제거 전: speech2_저속 스프레이 작업 소음 (직접).wav, STOI: 0.6806, PESQ: 1.0501
# 노이즈제거 후: speech2_저속 스프레이 작업 소음 (직접).wav, STOI: 0.8436, PESQ: 1.5792
# 노이즈제거 전: speech1_단열폼 분쇄기 소음.wav, STOI: 0.7463, PESQ: 1.2935
# 노이즈제거 후: speech1_단열폼 분쇄기 소음.wav, STOI: 0.8432, PESQ: 1.6996
# 노이즈제거 전: speech5_스프레이 작업 소음 (고음).wav, STOI: 0.6418, PESQ: 1.0449
# 노이즈제거 후: speech5_스프레이 작업 소음 (고음).wav, STOI: 0.7497, PESQ: 1.2889
# 노이즈제거 전: speech1_초고속 모터 작업 소음.wav, STOI: 0.7498, PESQ: 1.3202
# 노이즈제거 후: speech1_초고속 모터 작업 소음.wav, STOI: 0.8461, PESQ: 1.6417
# 노이즈제거 전: speech2_저속 스프레이 작업 소음 (장애물통과).wav, STOI: 0.7103, PESQ: 1.0497
# 노이즈제거 후: speech2_저속 스프레이 작업 소음 (장애물통과).wav, STOI: 0.8152, PESQ: 1.3857
# 노이즈제거 전: speech2_단열폼 미장 소음.wav, STOI: 0.7222, PESQ: 1.0699
# 노이즈제거 후: speech2_단열폼 미장 소음.wav, STOI: 0.8909, PESQ: 1.6442
# 노이즈제거 전: speech5_단열폼 미장 소음.wav, STOI: 0.6390, PESQ: 1.0863
# 노이즈제거 후: speech5_단열폼 미장 소음.wav, STOI: 0.7480, PESQ: 1.5655
# 노이즈제거 전: speech3_초고속 모터 작업 소음.wav, STOI: 0.7271, PESQ: 1.3112
# 노이즈제거 후: speech3_초고속 모터 작업 소음.wav, STOI: 0.8112, PESQ: 1.7065
# 노이즈제거 전: speech4_스프레이 마감작업 소음.wav, STOI: 0.6222, PESQ: 1.1070
# 노이즈제거 후: speech4_스프레이 마감작업 소음.wav, STOI: 0.7847, PESQ: 1.3861
# 노이즈제거 전: speech5_스프레이 작업 소음 (저음).wav, STOI: 0.6273, PESQ: 1.0357
# 노이즈제거 후: speech5_스프레이 작업 소음 (저음).wav, STOI: 0.7360, PESQ: 1.1932

# %%
import os

if __name__ == "__main__":
    SIG_DIR = "sounds/before_noise"
    NOISY_DIR = "sounds/after_noise"
    NOISE_DIR = "sounds/noise/noise_clip"
    TARGET_DIR = "sounds/after_noise_denoised"
    
    for file in os.listdir(NOISY_DIR):
        if not file.endswith(".wav"):
            continue
        clean_file = os.path.join(SIG_DIR, f'{file.split("_")[0]}.wav')
        noisy_file = os.path.join(NOISY_DIR, file)
        si_sdr_score = measure_si_sdr(clean_file, noisy_file)
        denoised_file = os.path.join(TARGET_DIR, file)
        denoised_si_sdr_score = measure_si_sdr(clean_file, denoised_file)
        print(f"노이즈제거 전: {file}, SI-SDR: {si_sdr_score:.4f}")
        print(f"노이즈제거 후: {file}, SI-SDR: {denoised_si_sdr_score:.4f}")
# Out:
# 노이즈제거 전: speech4_단열폼 미장 소음.wav, SI-SDR: -2.9846
# 노이즈제거 후: speech4_단열폼 미장 소음.wav, SI-SDR: -0.3845
# 노이즈제거 전: speech4_대형 환기팬 및 설비 소음.wav, SI-SDR: -3.1377
# 노이즈제거 후: speech4_대형 환기팬 및 설비 소음.wav, SI-SDR: 1.8493
# 노이즈제거 전: speech3_보온 작업 근접 소음 및 선박 망치질.wav, SI-SDR: -3.0656
# 노이즈제거 후: speech3_보온 작업 근접 소음 및 선박 망치질.wav, SI-SDR: 7.3190
# 노이즈제거 전: speech5_보온 작업 근접 소음 및 선박 망치질.wav, SI-SDR: -2.8758
# 노이즈제거 후: speech5_보온 작업 근접 소음 및 선박 망치질.wav, SI-SDR: 4.2861
# 노이즈제거 전: speech3_대형 환기팬 및 설비 소음.wav, SI-SDR: -2.9607
# 노이즈제거 후: speech3_대형 환기팬 및 설비 소음.wav, SI-SDR: 9.0310
# 노이즈제거 전: speech4_스프레이 작업 소음 (고음).wav, SI-SDR: -3.0067
# 노이즈제거 후: speech4_스프레이 작업 소음 (고음).wav, SI-SDR: 6.0086
# 노이즈제거 전: speech5_대형 환기팬 및 설비 소음.wav, SI-SDR: -3.1416
# 노이즈제거 후: speech5_대형 환기팬 및 설비 소음.wav, SI-SDR: 6.1515
# 노이즈제거 전: speech2_초고속 모터 작업 소음.wav, SI-SDR: -3.0584
# 노이즈제거 후: speech2_초고속 모터 작업 소음.wav, SI-SDR: 7.3895
# 노이즈제거 전: speech3_저속 스프레이 작업 소음 (직접).wav, SI-SDR: -3.1215
# 노이즈제거 후: speech3_저속 스프레이 작업 소음 (직접).wav, SI-SDR: 7.2390
# 노이즈제거 전: speech3_스프레이 작업 소음 (저음).wav, SI-SDR: -2.9467
# 노이즈제거 후: speech3_스프레이 작업 소음 (저음).wav, SI-SDR: 7.2854
# 노이즈제거 전: speech2_스프레이 마감작업 소음.wav, SI-SDR: -2.9720
# 노이즈제거 후: speech2_스프레이 마감작업 소음.wav, SI-SDR: 12.2297
# 노이즈제거 전: speech4_단열폼 분쇄기 소음.wav, SI-SDR: -2.8825
# 노이즈제거 후: speech4_단열폼 분쇄기 소음.wav, SI-SDR: 3.8723
# 노이즈제거 전: speech4_보온 작업 근접 소음 및 선박 망치질.wav, SI-SDR: -2.9090
# 노이즈제거 후: speech4_보온 작업 근접 소음 및 선박 망치질.wav, SI-SDR: 2.1129
# 노이즈제거 전: speech3_단열폼 분쇄기 소음.wav, SI-SDR: -3.0193
# 노이즈제거 후: speech3_단열폼 분쇄기 소음.wav, SI-SDR: 9.1749
# 노이즈제거 전: speech5_초고속 모터 작업 소음.wav, SI-SDR: -2.9719
# 노이즈제거 후: speech5_초고속 모터 작업 소음.wav, SI-SDR: 5.2209
# 노이즈제거 전: speech1_보온 작업 근접 소음 및 선박 망치질.wav, SI-SDR: -3.0335
# 노이즈제거 후: speech1_보온 작업 근접 소음 및 선박 망치질.wav, SI-SDR: 4.7919
# 노이즈제거 전: speech1_저속 스프레이 작업 소음 (장애물통과).wav, SI-SDR: -3.0672
# 노이즈제거 후: speech1_저속 스프레이 작업 소음 (장애물통과).wav, SI-SDR: 6.2582
# 노이즈제거 전: speech1_스프레이 작업 소음 (저음).wav, SI-SDR: -2.9771
# 노이즈제거 후: speech1_스프레이 작업 소음 (저음).wav, SI-SDR: 5.4428
# 노이즈제거 전: speech2_보온 작업 근접 소음 및 선박 망치질.wav, SI-SDR: -2.9304
# 노이즈제거 후: speech2_보온 작업 근접 소음 및 선박 망치질.wav, SI-SDR: 7.2705
# 노이즈제거 전: speech4_스프레이 작업 소음 (저음).wav, SI-SDR: -2.9633
# 노이즈제거 후: speech4_스프레이 작업 소음 (저음).wav, SI-SDR: 1.6728
# 노이즈제거 전: speech3_단열폼 미장 소음.wav, SI-SDR: -3.0417
# 노이즈제거 후: speech3_단열폼 미장 소음.wav, SI-SDR: 7.5717
# 노이즈제거 전: speech2_스프레이 작업 소음 (저음).wav, SI-SDR: -3.0323
# 노이즈제거 후: speech2_스프레이 작업 소음 (저음).wav, SI-SDR: 6.9819
# 노이즈제거 전: speech1_단열폼 미장 소음.wav, SI-SDR: -3.0574
# 노이즈제거 후: speech1_단열폼 미장 소음.wav, SI-SDR: 7.8016
# 노이즈제거 전: speech5_단열폼 분쇄기 소음.wav, SI-SDR: -3.1902
# 노이즈제거 후: speech5_단열폼 분쇄기 소음.wav, SI-SDR: 5.7021
# 노이즈제거 전: speech5_저속 스프레이 작업 소음 (직접).wav, SI-SDR: -3.1856
# 노이즈제거 후: speech5_저속 스프레이 작업 소음 (직접).wav, SI-SDR: 4.6447
# 노이즈제거 전: speech1_스프레이 작업 소음 (고음).wav, SI-SDR: -2.9396
# 노이즈제거 후: speech1_스프레이 작업 소음 (고음).wav, SI-SDR: 5.6652
# 노이즈제거 전: speech2_스프레이 작업 소음 (고음).wav, SI-SDR: -2.9710
# 노이즈제거 후: speech2_스프레이 작업 소음 (고음).wav, SI-SDR: 7.4318
# 노이즈제거 전: speech1_대형 환기팬 및 설비 소음.wav, SI-SDR: -2.9830
# 노이즈제거 후: speech1_대형 환기팬 및 설비 소음.wav, SI-SDR: 6.2124
# 노이즈제거 전: speech4_초고속 모터 작업 소음.wav, SI-SDR: -2.9390
# 노이즈제거 후: speech4_초고속 모터 작업 소음.wav, SI-SDR: 3.2194
# 노이즈제거 전: speech4_저속 스프레이 작업 소음 (장애물통과).wav, SI-SDR: -3.2620
# 노이즈제거 후: speech4_저속 스프레이 작업 소음 (장애물통과).wav, SI-SDR: 4.1078
# 노이즈제거 전: speech1_스프레이 마감작업 소음.wav, SI-SDR: -2.9741
# 노이즈제거 후: speech1_스프레이 마감작업 소음.wav, SI-SDR: 7.6375
# 노이즈제거 전: speech3_스프레이 마감작업 소음.wav, SI-SDR: -2.9843
# 노이즈제거 후: speech3_스프레이 마감작업 소음.wav, SI-SDR: 11.1810
# 노이즈제거 전: speech2_단열폼 분쇄기 소음.wav, SI-SDR: -3.0422
# 노이즈제거 후: speech2_단열폼 분쇄기 소음.wav, SI-SDR: 8.2486
# 노이즈제거 전: speech1_저속 스프레이 작업 소음 (직접).wav, SI-SDR: -3.0816
# 노이즈제거 후: speech1_저속 스프레이 작업 소음 (직접).wav, SI-SDR: 5.2368
# 노이즈제거 전: speech2_대형 환기팬 및 설비 소음.wav, SI-SDR: -2.9337
# 노이즈제거 후: speech2_대형 환기팬 및 설비 소음.wav, SI-SDR: 8.0495
# 노이즈제거 전: speech5_스프레이 마감작업 소음.wav, SI-SDR: -3.0509
# 노이즈제거 후: speech5_스프레이 마감작업 소음.wav, SI-SDR: 7.2681
# 노이즈제거 전: speech4_저속 스프레이 작업 소음 (직접).wav, SI-SDR: -3.0371
# 노이즈제거 후: speech4_저속 스프레이 작업 소음 (직접).wav, SI-SDR: 1.2056
# 노이즈제거 전: speech3_스프레이 작업 소음 (고음).wav, SI-SDR: -3.2037
# 노이즈제거 후: speech3_스프레이 작업 소음 (고음).wav, SI-SDR: 7.7168
# 노이즈제거 전: speech3_저속 스프레이 작업 소음 (장애물통과).wav, SI-SDR: -3.1697
# 노이즈제거 후: speech3_저속 스프레이 작업 소음 (장애물통과).wav, SI-SDR: 6.6086
# 노이즈제거 전: speech5_저속 스프레이 작업 소음 (장애물통과).wav, SI-SDR: -3.0621
# 노이즈제거 후: speech5_저속 스프레이 작업 소음 (장애물통과).wav, SI-SDR: 5.0794
# 노이즈제거 전: speech2_저속 스프레이 작업 소음 (직접).wav, SI-SDR: -2.9669
# 노이즈제거 후: speech2_저속 스프레이 작업 소음 (직접).wav, SI-SDR: 6.2766
# 노이즈제거 전: speech1_단열폼 분쇄기 소음.wav, SI-SDR: -3.0778
# 노이즈제거 후: speech1_단열폼 분쇄기 소음.wav, SI-SDR: 6.2010
# 노이즈제거 전: speech5_스프레이 작업 소음 (고음).wav, SI-SDR: -2.9413
# 노이즈제거 후: speech5_스프레이 작업 소음 (고음).wav, SI-SDR: 5.4039
# 노이즈제거 전: speech1_초고속 모터 작업 소음.wav, SI-SDR: -2.9701
# 노이즈제거 후: speech1_초고속 모터 작업 소음.wav, SI-SDR: 5.9893
# 노이즈제거 전: speech2_저속 스프레이 작업 소음 (장애물통과).wav, SI-SDR: -2.9179
# 노이즈제거 후: speech2_저속 스프레이 작업 소음 (장애물통과).wav, SI-SDR: 6.3686
# 노이즈제거 전: speech2_단열폼 미장 소음.wav, SI-SDR: -2.9245
# 노이즈제거 후: speech2_단열폼 미장 소음.wav, SI-SDR: 10.2261
# 노이즈제거 전: speech5_단열폼 미장 소음.wav, SI-SDR: -3.0634
# 노이즈제거 후: speech5_단열폼 미장 소음.wav, SI-SDR: 4.8008
# 노이즈제거 전: speech3_초고속 모터 작업 소음.wav, SI-SDR: -2.9371
# 노이즈제거 후: speech3_초고속 모터 작업 소음.wav, SI-SDR: 8.9447
# 노이즈제거 전: speech4_스프레이 마감작업 소음.wav, SI-SDR: -2.9017
# 노이즈제거 후: speech4_스프레이 마감작업 소음.wav, SI-SDR: 5.6982
# 노이즈제거 전: speech5_스프레이 작업 소음 (저음).wav, SI-SDR: -3.0074
# 노이즈제거 후: speech5_스프레이 작업 소음 (저음).wav, SI-SDR: 4.8517
